# %% [markdown]
# # Python Fundamentals: Print Formatting & Practice
#
# Extra practice with print formatting, swapping variables, and string/list operations.
#
# **Covers:**
# - Print formatting variations (positional args, `.format()`)
# - Swapping variables (temp variable vs. tuple-unpacking methods)
# - Reading multiple values and casting types
# - String immutability, slicing, and deletion
# - List creation: homogeneous, heterogeneous, and nested lists

# %%
print("hi",end='!!!!')
print('HELLO')

# %%
a = 10
b = 4.567
c = 2+4j
d = "hello all"

# %%
#dynamically pgm Language
print(a,b,c,d)
# Out:
# 10 4.567 (2+4j) hello all

# %%
print('a=',a,'b=',b,'c=',c,'d=',d)
# Out:
# a= 10 b= 4.567 c= (2+4j) d= hello all

# %%
print('\na=',a,'\nb=',b,'\nc=',c,'\nd=',d)
# Out:
# a= 10
# b= 4.567
# c= (2+4j)
# d= hello all

# %%
#formatting
print("a={0}\nb={1}\nc={2}\nd={3}".format(a,b,c,d))
# Out:
# a=10
# b=4.567
# c=(2+4j)
# d=hello all

# %%
print("a={}\nb={}\nc={}\nd={}".format(a,b,c,d))
# Out:
# a=10
# b=4.567
# c=(2+4j)
# d=hello all

# %%
print("a={2}\nb={1}\nc={2}\nd={0}".format(a,b,c,d))
# Out:
# a=(2+4j)
# b=4.567
# c=(2+4j)
# d=10

# %%
name = "Aditi"  # demo value (Kaggle-safe: was interactive input())
age = 21  # demo value (Kaggle-safe: was interactive int(input()))
# Out:
# Enter the name of the student: Zaafir
# Enter the age of the student: 20

# %%
print("Student name = {}\nAge = {}".format(name,age))
# Out:
# Student name = Zaafir
# Age = 20

# %%
''' implement a python code to read two integers from user
and swap the numbers. Display the original data and
swapped data.'''
a = 15  # demo value (Kaggle-safe: was interactive eval(input()))
b = 42  # demo value (Kaggle-safe: was interactive eval(input()))
# Out:
# Enter the data:  10
# Enter the data:  20

# %%
print("\nData before Swapping: \na = {}\nb = {}".format(a,b))
temp = a
a = b
b = temp
print("\nData after Swapping: \na = {}\nb = {}".format(a,b))
# Out:
# Data before Swapping:
# a = 10
# b = 20
#
# Data after Swapping:
# a = 20
# b = 10

# %%
print("\nData before Swapping: \na = {}\nb = {}".format(a,b))
a,b=b,a
print("\nData after Swapping: \na = {}\nb = {}".format(a,b))
# Out:
# Data before Swapping:
# a = 20
# b = 10
#
# Data after Swapping:
# a = 10
# b = 20

# %%
#Read the age of 3 people
p1 = 25  # demo value (Kaggle-safe: was interactive int(input()))
p2 = 30  # demo value (Kaggle-safe: was interactive int(input()))

p3 = 22  # demo value (Kaggle-safe: was interactive int(input()))
# Out:
# Enter p1 Age:  20
# Enter p2 Age:  21
# Enter p3 Age:  22

# %%
print("P1 Age = {}\nP2 Age = {}\nP3 Age = {}".format(p1,p2,p3))
# Out:
# P1 Age = 20
# P2 Age = 21
# P3 Age = 22

# %%
ages = "25 30 22".split(' ')  # demo value (Kaggle-safe: was interactive input().split())
# Out:
# Enter 3 Ages Seperated by commas: 1 2 3

# %%
type(ages)
# Out:
# list

# %%
print(ages)
# Out:
# ['1', '2', '3']

# %%
ages[0] = int(ages[0])
ages[1] = int(ages[1])

# %%
print(type(ages))
print(type(ages[0]))
print(type(ages[1]))
print(type(ages[2]))
# Out:
# <class 'list'>
# <class 'int'>
# <class 'int'>
# <class 'str'>

# %%
print(ages)
# Out:
# [1, 2, '3']

# %%
ages[2] = int(ages[2])
print(ages)
# Out:
# [1, 2, 3]

# %%
#list Uncovering
s1,s2,s3 = "25 30 22".split(' ')  # demo value (Kaggle-safe: was interactive input().split())
# Out:
# Enter 3 numbers seperated by space:  1 2 3

# %%
print(type(s1))
print(s1)
print(s2)
print(s3)
# Out:
# <class 'str'>
# 1
# 2
# 3

# %%
s1 = int(s1)
s2 = int(s2)
s3 = int(s3)
print(type(s1))
print(s1)
print(s2)
print(s3)
# Out:
# <class 'int'>
# 1
# 2
# 3

# %%
#list Uncovering
l=[1,2,3]

# %%
a,b,c=l

# %%
print(1)
print(2)
print(3)
# Out:
# 1
# 2
# 3

# %%
#Printive Data types/Data Structures in python
#string
s1 = 'hi'
s2 = "hello"
s3 = '''hi
hello
all'''
print(s1)
# Out:
# hi

# %%
print(s2)
# Out:
# hello

# %%
print(s3)
# Out:
# hi
# hello
# all

# %%
#Access string elements
#Indexing Technique
print("The 1st element of s1= ",s1[0])
# Out:
# The 1st element of s1=  h

# %%
#String slicing
print(s2[0:3:1])
print(s2[-1:-5:-2])
# Out:
# hel
# ol

# %%
print(s3[0:10:1])
# Out:
# hi
# hello
# a

# %%
print(s3[-1::-1])
# Out:
# lla
# olleh
# ih

# %%
# string is immutable so we cannot change or modify once a string is created
#s2[0]='p'

# %%
# also String data cannot be deleted 
#del s2[0]

# %%
#but string as a whole can be deleted
del s2

# %%
# name error since we deleted s2 and there is no such variable present after deletion
#print(s2)

# %%
''' Implement a python code to read a string from user and reverse the string.
Display the original and reversed string'''
s = "hello world"  # demo value (Kaggle-safe: was interactive input())
print("String before Reversing: ",s)
s=s[-1::-1]
print("String after Reversing: ",s)
# Out:
# Enter the string abbc
# String before Reversing:  abbc
# String after Reversing:  cbba

# %%
s = "python programming"  # demo value (Kaggle-safe: was interactive input())
print("Original string: ",s)
print("Reversed string: ",s[-1::-1])
# Out:
# Enter a string:  hello
# Original string:  hello
# Reversed string:  olleh

# %%
#Arithmetic Operator
#+
#-
#*
#/
#%
#//
#**

# %%
a=5
b=2

# %%
print(a/b)
# Out:
# 2.5

# %%
print(a//b)
# Out:
# 2

# %%
# + concatenates when used between 2 strings
s1 = 'hi'
s2 = 'hello'
print(s1+s2)
# Out:
# hihello

# %%
# * multiplies the string when multiplied with numbers
print(s1*2)
# Out:
# hihi

# %%
s="hello"
#membership operator
#in ---- returns True if item found in sequence data, else returns False
#not in ---- returns True if item not found in sequence data,else returns False
if 'h' in s:
    print("YES")
else:
    print("NO")
# Out:
# YES

# %%
print('h' in s)
# Out:
# True

# %%
print('h' not in s)
# Out:
# False

# %%
#list
#Oredered collection of similar or different types of data
#mutable

# %%
#create a homogeneous,heterogeneous & nested List
#Homogeneous List
l1=[1,2,3]
#Heterogeneous List
l2=[1,2.3,'a',2+4j]
#Nested List
l3=[[1,2,3],['a','b','c'],1+3j]
print(l1)
print(l2)
print(l3)
print(l3[0])
print(l3[0][2])
# Out:
# [1, 2, 3]
# [1, 2.3, 'a', (2+4j)]
# [[1, 2, 3], ['a', 'b', 'c'], (1+3j)]
# [1, 2, 3]
# 3
